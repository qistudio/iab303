# %% [markdown]
# <div class="alert alert-block alert-info">IAB303 - Business Intelligence - <a href="0%20-%20IAB303%20Overview.ipynb">overview</a></div>

# %% [markdown]
# ## PRACTICAL :: Introducing Jupyter notebook
#
# You've made it to this point, so you know how to access notebooks from the Jupyter `files` page. Now it's time to take a look at how these notebooks are created.
#
# Notebooks have 2 main types of cells - `Markdown` cells for displaying content like a web page, and `Code` cells for running code (in our case Python code) and displaying the results. In this practical session we will explore both of these types of cells and how they work together for a complete analytics process.
#
# This PRAC includes 3 groups of tasks:
# 1. Basic Markdown
# 2. Basic Python
# 3. Overview of analytics process
#
# Before moving on to the tasks, familiarise yourself with the menus above, and in particular the keyboard short cuts (click the keyboard icon) for `run cell and insert below`, `run cell and select next`, changing between `command` and `edit` modes, and changing between `Code` and `Markdown` cell types.
#
# ---

# %% [markdown]
# ## [1] Basic Markdown
#
# Open this [link on markdown cells](http://nbviewer.jupyter.org/github/ipython/ipython/blob/3.x/examples/Notebook/Working%20With%20Markdown%20Cells.ipynb) in a new tab or window, and read what is possible to do in a markdown cell. Click the `</>` symbol on the top right of the page to view the markdown code that is used to create the markdown.
#
# Try creating the following markdown elements. Create a new markdown cell for each element:
# 1. Headings - 3 different levels. Then give each subsequent element a heading
# 2. Plain text, italics and bold text, and a horizontal line. Then put a line between each element.
# 3. A numbered list of your 3 favourite bands/musicians, with sublists of a couple of their albums
# 4. A bulleted list of your 3 favourite movies, with sublists of characters in each.
# 5. A table with your movies above, your favourite character and the actor who plays the character.
# 6. A quote from a web page, and a link to the original webpage
# 7. A code block that demonstrates printing your name
# 8. An inline maths equation for a quadratic equation - f of x equals ax squared plus bx plus c (between some text)
#
# ---

# %% [markdown]
# Add your Markdown here.

# %% [markdown]
# ## [2] Basic Python
#
# Open this [link on introductory Python](https://docs.python.org/3.6/tutorial/introduction.html) in a new tab or window, and read about some basic Python.
#
# Try running Python code for the following tasks. Create a new `Code` cell for each task.
#
# 1. Code comments. Include one at the start of the cell and another beside `answer = 42` that tells the read that it is the answer to life, the universe and everything.
# 2. Calculate the number hours in a week. Assign this to a variable `hoursInWeek`, and then calculate the number of hours in a 13 week semester. Comment what you are doing.
# 3. Create a 2 line string using newline and print it out.
# 4. Create a 3 line string using triple quotes and print it out.
# 5. Print out `Business Intelligence` concatenated from 4 parts.
# 6. Assign `IAB303 Business Intelligence` to a variable `unit` and then extract the unit code separated to the unit name and print them out as `Business Intelligence (IAB303)`.
# 7. Check that the unit code is 6 characters long.
# 8. Add your movies from the markdown task to a list, then use a while loop to print each element of the list out on a separate line.

# %%
#Write your code here

# %% [markdown]
# ## [3] Overview of analytics process
#
# > **CONCERN:** The business is looking to launch an agricultural product in either Australia or New Zealand. However, management is unsure which country to start with.
#
# Complete each of the following steps to get an overview of the analytics process.
# 1. Load data
# 2. Clean/preprocess data
# 3. Perform analysis
# 4. Visualise analytics
# 5. Document analytics

# %% [markdown]
# ### Load data
#
# [GapMinder](https://www.gapminder.org/data/) - (based on [uw-madison resource](https://uw-madison-aci.github.io/python-novice-gapminder/39-plotting/))
# * Agriculture, percent of GDP (`prac1-data1.csv`)

# %%
# Import pandas for dataframes and matplotlib for plotting
import matplotlib.pyplot as plt
import pandas

# Set variables for file and index column
file = 'prac1-data.csv' #see above
colname = 'Agriculture, value added (% of GDP)' #open the csv and have a look

# Read in the percent of gdp data
ag_gdp = pandas.read_csv(file, index_col= colname)
print(ag_gdp.shape)
# Out:
# (270, 51)

# %%
# Take a look at the data
ag_gdp
# Out:
#                                           1961       1962       1963  \
# Agriculture, value added (% of GDP)
# Abkhazia                                   NaN        NaN        NaN
# Afghanistan                                NaN        NaN        NaN
# Akrotiri and Dhekelia                      NaN        NaN        NaN
# Albania                                    NaN        NaN        NaN
# Algeria                                    NaN        NaN        NaN
# American Samoa                             NaN        NaN        NaN
# Andorra                                    NaN        NaN        NaN
# Angola                                     NaN        NaN        NaN
# Anguilla                                   NaN        NaN        NaN
# Antigua and Barbuda                        NaN        NaN        NaN
# Argentina                                  NaN        NaN        NaN
# Armenia                                    NaN        NaN        NaN
# Aruba                                      NaN        NaN        NaN
# Australia                                  NaN        NaN        NaN
# Austria                                    NaN        NaN        NaN
# Azerbaijan                                 NaN        NaN        NaN
# Bahamas                                    NaN        NaN        NaN
# Bahrain                                    NaN        NaN        NaN
# Bangladesh                                 NaN        NaN        NaN
# Barbados                             20.249653  19.356999  23.072430
# Belarus                                    NaN        NaN        NaN
# Belgium                                    NaN        NaN        NaN
# Belize                                     NaN        NaN        NaN
# Benin                                46.193786  44.709273  43.718370
# Bermuda                                    NaN        NaN        NaN
# Bhutan                                     NaN        NaN        NaN
# Bolivia                                    NaN        NaN        NaN
# Bosnia and Herzegovina                     NaN        NaN        NaN
# Botswana                             41.870602  40.456968  39.380814
# Brazil                               19.496612  17.350489  16.793914
# ...                                        ...        ...        ...
# United States                              NaN        NaN        NaN
# Uruguay                                    NaN        NaN        NaN
# USSR                                       NaN        NaN        NaN
# Uzbekistan                                 NaN        NaN        NaN
# Wallis et Futuna                           NaN        NaN        NaN
# Vanuatu                                    NaN        NaN        NaN
# Venezuela                             4.934940   4.902952   5.080288
# West Bank and Gaza                         NaN        NaN        NaN
# West Germany                               NaN        NaN        NaN
# Western Sahara                             NaN        NaN        NaN
# Vietnam                                    NaN        NaN        NaN
# Virgin Islands (U.S.)                      NaN        NaN        NaN
# North Yemen (former)                       NaN        NaN        NaN
# South Yemen (former)                       NaN        NaN        NaN
# Yemen                                      NaN        NaN        NaN
# Yugoslavia                                 NaN        NaN        NaN
# Zambia                                     NaN        NaN        NaN
# Zimbabwe                                   NaN        NaN        NaN
# Åland                                      NaN        NaN        NaN
# South Sudan                                NaN        NaN        NaN
# Christian                                  NaN        NaN        NaN
# Coastline                                  NaN        NaN        NaN
# Curaçao                                    NaN        NaN        NaN
# Sint Maarten (Dutch part)                  NaN        NaN        NaN
# St. Martin (French part)                   NaN        NaN        NaN
# Antarctica                                 NaN        NaN        NaN
# Virgin Islands, British                    NaN        NaN        NaN
# Hawaiian Trade Zone                        NaN        NaN        NaN
# U.S. Pacific Islands                       NaN        NaN        NaN
# Wake Island                                NaN        NaN        NaN
#
#                                           1964       1965       1966  \
# Agriculture, value added (% of GDP)
# Abkhazia                                   NaN        NaN        NaN
# Afghanistan                                NaN        NaN        NaN
# Akrotiri and Dhekelia                      NaN        NaN        NaN
# Albania                                    NaN        NaN        NaN
# Algeria                                    NaN  12.876213   9.137256
# American Samoa                             NaN        NaN        NaN
# Andorra                                    NaN        NaN        NaN
# Angola                                     NaN        NaN        NaN
# Anguilla                                   NaN        NaN        NaN
# Antigua and Barbuda                        NaN        NaN        NaN
# Argentina                                  NaN  12.904163  10.278586
# Armenia                                    NaN        NaN        NaN
# Aruba                                      NaN        NaN        NaN
# Australia                                  NaN        NaN        NaN
# Austria                                    NaN        NaN        NaN
# Azerbaijan                                 NaN        NaN        NaN
# Bahamas                                    NaN        NaN        NaN
# Bahrain                                    NaN        NaN        NaN
# Bangladesh                                 NaN        NaN        NaN
# Barbados                             19.880952  20.011274  19.621252
# Belarus                                    NaN        NaN        NaN
# Belgium                                    NaN        NaN        NaN
# Belize                                     NaN        NaN        NaN
# Benin                                45.528152  44.619425  45.147820
# Bermuda                                    NaN        NaN        NaN
# Bhutan                                     NaN        NaN        NaN
# Bolivia                                    NaN        NaN        NaN
# Bosnia and Herzegovina                     NaN        NaN        NaN
# Botswana                             38.430411  33.841463  39.295393
# Brazil                               17.286118  18.709918  15.692939
# ...                                        ...        ...        ...
# United States                              NaN        NaN        NaN
# Uruguay                                    NaN        NaN        NaN
# USSR                                       NaN        NaN        NaN
# Uzbekistan                                 NaN        NaN        NaN
# Wallis et Futuna                           NaN        NaN        NaN
# Vanuatu                                    NaN        NaN        NaN
# Venezuela                             5.098463   5.321558   5.642903
# West Bank and Gaza                         NaN        NaN        NaN
# West Germany                               NaN        NaN        NaN
# Western Sahara                             NaN        NaN        NaN
# Vietnam                                    NaN        NaN        NaN
# Virgin Islands (U.S.)                      NaN        NaN        NaN
# North Yemen (former)                       NaN        NaN        NaN
# South Yemen (former)                       NaN        NaN        NaN
# Yemen                                      NaN        NaN        NaN
# Yugoslavia                                 NaN        NaN        NaN
# Zambia                                     NaN  15.634006  14.691358
# Zimbabwe                                   NaN  20.125821  21.953760
# Åland                                      NaN        NaN        NaN
# South Sudan                                NaN        NaN        NaN
# Christian                                  NaN        NaN        NaN
# Coastline                                  NaN        NaN        NaN
# Curaçao                                    NaN        NaN        NaN
# Sint Maarten (Dutch part)                  NaN        NaN        NaN
# St. Martin (French part)                   NaN        NaN        NaN
# Antarctica                                 NaN        NaN        NaN
# Virgin Islands, British                    NaN        NaN        NaN
# Hawaiian Trade Zone                        NaN        NaN        NaN
# U.S. Pacific Islands                       NaN        NaN        NaN
# Wake Island                                NaN        NaN        NaN
#
#                                           1967       1968       1969  \
# Agriculture, value added (% of GDP)
# Abkhazia                                   NaN        NaN        NaN
# Afghanistan                                NaN        NaN        NaN
# Akrotiri and Dhekelia                      NaN        NaN        NaN
# Albania                                    NaN        NaN        NaN
# Algeria                              10.330666  10.853374   9.030165
# American Samoa                             NaN        NaN        NaN
# Andorra                                    NaN        NaN        NaN
# Angola                                     NaN        NaN        NaN
# Anguilla                                   NaN        NaN        NaN
# Antigua and Barbuda                        NaN        NaN        NaN
# Argentina                             9.980386   9.721277   9.185893
# Armenia                                    NaN        NaN        NaN
# Aruba                                      NaN        NaN        NaN
# Australia                                  NaN        NaN        NaN
# Austria                                    NaN        NaN        NaN
# Azerbaijan                                 NaN        NaN        NaN
# Bahamas                                    NaN        NaN        NaN
# Bahrain                                    NaN        NaN        NaN
# Bangladesh                                 NaN        NaN        NaN
# Barbados                             19.189567  14.626263  11.964874
# Belarus                                    NaN        NaN        NaN
# Belgium                                    NaN        NaN        NaN
# Belize                                     NaN        NaN        NaN
# Benin                                42.081013  38.868069  38.496663
# Bermuda                                    NaN        NaN        NaN
# Bhutan                                     NaN        NaN        NaN
# Bolivia                                    NaN        NaN        NaN
# Bosnia and Herzegovina                     NaN        NaN        NaN
# Botswana                                   NaN        NaN        NaN
# Brazil                               15.108760  14.050292  13.215907
# ...                                        ...        ...        ...
# United States                              NaN        NaN        NaN
# Uruguay                                    NaN        NaN        NaN
# USSR                                       NaN        NaN        NaN
# Uzbekistan                                 NaN        NaN        NaN
# Wallis et Futuna                           NaN        NaN        NaN
# Vanuatu                                    NaN        NaN        NaN
# Venezuela                             5.876246   5.971564   6.472197
# West Bank and Gaza                         NaN        NaN        NaN
# West Germany                               NaN        NaN        NaN
# Western Sahara                             NaN        NaN        NaN
# Vietnam                                    NaN        NaN        NaN
# Virgin Islands (U.S.)                      NaN        NaN        NaN
# North Yemen (former)                       NaN        NaN        NaN
# South Yemen (former)                       NaN        NaN        NaN
# Yemen                                      NaN        NaN        NaN
# Yugoslavia                                 NaN        NaN        NaN
# Zambia                               14.025086  12.439261  10.555556
# Zimbabwe                             22.894207  17.783044  20.445870
# Åland                                      NaN        NaN        NaN
# South Sudan                                NaN        NaN        NaN
# Christian                                  NaN        NaN        NaN
# Coastline                                  NaN        NaN        NaN
# Curaçao                                    NaN        NaN        NaN
# Sint Maarten (Dutch part)                  NaN        NaN        NaN
# St. Martin (French part)                   NaN        NaN        NaN
# Antarctica                                 NaN        NaN        NaN
# Virgin Islands, British                    NaN        NaN        NaN
# Hawaiian Trade Zone                        NaN        NaN        NaN
# U.S. Pacific Islands                       NaN        NaN        NaN
# Wake Island                                NaN        NaN        NaN
#
#                                           1970    ...           2002  \
# Agriculture, value added (% of GDP)               ...
# Abkhazia                                   NaN    ...            NaN
# Afghanistan                                NaN    ...      45.158479
# Akrotiri and Dhekelia                      NaN    ...            NaN
# Albania                                    NaN    ...      26.311622
# Algeria                               9.205466    ...      10.003598
# American Samoa                             NaN    ...            NaN
# Andorra                                    NaN    ...            NaN
# Angola                                     NaN    ...       7.853170
# Anguilla                                   NaN    ...            NaN
# Antigua and Barbuda                        NaN    ...       1.953523
# Argentina                             9.637561    ...      10.683021
# Armenia                                    NaN    ...      25.961899
# Aruba                                      NaN    ...            NaN
# Australia                                  NaN    ...       4.438795
# Austria                               7.830931    ...       1.935255
# Azerbaijan                                 NaN    ...      15.171677
# Bahamas                                    NaN    ...       3.123889
# Bahrain                                    NaN    ...            NaN
# Bangladesh                                 NaN    ...      22.730417
# Barbados                             10.972179    ...       3.762901
# Belarus                                    NaN    ...      11.775276
# Belgium                               4.020534    ...       1.174805
# Belize                                     NaN    ...      14.772046
# Benin                                36.327852    ...      33.760924
# Bermuda                                    NaN    ...       0.835399
# Bhutan                                     NaN    ...      26.981548
# Bolivia                              20.783000    ...      14.898786
# Bosnia and Herzegovina                     NaN    ...      10.089153
# Botswana                                   NaN    ...       2.006504
# Brazil                               12.345263    ...       6.617711
# ...                                        ...    ...            ...
# United States                         3.542820    ...       1.009241
# Uruguay                                    NaN    ...       8.685456
# USSR                                       NaN    ...            NaN
# Uzbekistan                                 NaN    ...      34.251727
# Wallis et Futuna                           NaN    ...            NaN
# Vanuatu                                    NaN    ...      24.002196
# Venezuela                             6.108787    ...       4.103337
# West Bank and Gaza                         NaN    ...            NaN
# West Germany                               NaN    ...            NaN
# Western Sahara                             NaN    ...            NaN
# Vietnam                                    NaN    ...      23.033311
# Virgin Islands (U.S.)                      NaN    ...            NaN
# North Yemen (former)                       NaN    ...            NaN
# South Yemen (former)                       NaN    ...            NaN
# Yemen                                      NaN    ...      13.342070
# Yugoslavia                                 NaN    ...            NaN
# Zambia                               11.632479    ...      22.068937
# Zimbabwe                             16.981599    ...      14.029007
# Åland                                      NaN    ...            NaN
# South Sudan                                NaN    ...            NaN
# Christian                                  NaN    ...            NaN
# Coastline                                  NaN    ...            NaN
# Curaçao                                    NaN    ...            NaN
# Sint Maarten (Dutch part)                  NaN    ...            NaN
# St. Martin (French part)                   NaN    ...            NaN
# Antarctica                                 NaN    ...            NaN
# Virgin Islands, British                    NaN    ...            NaN
# Hawaiian Trade Zone                        NaN    ...            NaN
# U.S. Pacific Islands                       NaN    ...            NaN
# Wake Island                                NaN    ...            NaN
#
#                                           2003       2004       2005  \
# Agriculture, value added (% of GDP)
# Abkhazia                                   NaN        NaN        NaN
# Afghanistan                          46.013843  41.594103  39.480416
# Akrotiri and Dhekelia                      NaN        NaN        NaN
# Albania                              23.996207  23.499999  22.800000
# Algeria                              10.491237  10.188493   8.221657
# American Samoa                             NaN        NaN        NaN
# Andorra                                    NaN        NaN        NaN
# Angola                                8.330555   8.626683   8.489994
# Anguilla                                   NaN        NaN        NaN
# Antigua and Barbuda                   1.986241   1.872183   2.024378
# Argentina                            10.986832  10.412916   9.401029
# Armenia                              23.682098  24.662200  20.892517
# Aruba                                      NaN        NaN        NaN
# Australia                             3.270656   3.480123   3.265037
# Austria                               1.850212   1.853935   1.605755
# Azerbaijan                           13.461515  11.842671   9.895473
# Bahamas                               2.765474   2.342788   2.194145
# Bahrain                                    NaN        NaN        NaN
# Bangladesh                           21.753293  21.036076  20.142033
# Barbados                              4.464019   3.542170   3.765042
# Belarus                              10.204042  10.328744   9.773649
# Belgium                               1.117454   1.108920   0.827944
# Belize                               16.633296  16.465625  15.299508
# Benin                                32.085691  32.083061  32.199867
# Bermuda                               0.862432   0.886889   0.841631
# Bhutan                               26.319898  25.582479  23.179131
# Bolivia                              15.418000  15.374656  14.378014
# Bosnia and Herzegovina                8.963526  10.735752  10.547855
# Botswana                              2.454870   2.030644   1.819170
# Brazil                                7.385968   6.913279   5.708391
# ...                                        ...        ...        ...
# United States                         1.197298   1.345075   1.212484
# Uruguay                              11.142992  12.875841  10.372541
# USSR                                       NaN        NaN        NaN
# Uzbekistan                           33.093886  30.773246  27.968567
# Wallis et Futuna                           NaN        NaN        NaN
# Vanuatu                              22.552758  23.337596  21.945259
# Venezuela                             4.555546   4.037468   4.022868
# West Bank and Gaza                         NaN        NaN        NaN
# West Germany                               NaN        NaN        NaN
# Western Sahara                             NaN        NaN        NaN
# Vietnam                              22.542437  21.807699  20.970173
# Virgin Islands (U.S.)                      NaN        NaN        NaN
# North Yemen (former)                       NaN        NaN        NaN
# South Yemen (former)                       NaN        NaN        NaN
# Yemen                                12.877023  11.730336  10.547667
# Yugoslavia                                 NaN        NaN        NaN
# Zambia                               22.574178  23.025551  23.318332
# Zimbabwe                             16.593401  19.575048  18.577279
# Åland                                      NaN        NaN        NaN
# South Sudan                                NaN        NaN        NaN
# Christian                                  NaN        NaN        NaN
# Coastline                                  NaN        NaN        NaN
# Curaçao                                    NaN        NaN        NaN
# Sint Maarten (Dutch part)                  NaN        NaN        NaN
# St. Martin (French part)                   NaN        NaN        NaN
# Antarctica                                 NaN        NaN        NaN
# Virgin Islands, British                    NaN        NaN        NaN
# Hawaiian Trade Zone                        NaN        NaN        NaN
# U.S. Pacific Islands                       NaN        NaN        NaN
# Wake Island                                NaN        NaN        NaN
#
#                                           2006       2007       2008  \
# Agriculture, value added (% of GDP)
# Abkhazia                                   NaN        NaN        NaN
# Afghanistan                          32.589058  34.494833  28.134488
# Akrotiri and Dhekelia                      NaN        NaN        NaN
# Albania                              22.000000  21.117256  20.304655
# Algeria                               7.988789   8.025346   6.920100
# American Samoa                             NaN        NaN        NaN
# Andorra                                    NaN        NaN        NaN
# Angola                                7.664511   7.860272   6.642216
# Anguilla                                   NaN        NaN        NaN
# Antigua and Barbuda                   1.910026   1.939082   1.838372
# Argentina                             8.392957   9.394875   9.837196
# Armenia                              20.451098  20.282060  18.398121
# Aruba                                      NaN        NaN        NaN
# Australia                             3.092147   2.367258   2.436576
# Austria                               1.635479   1.746160   1.712201
# Azerbaijan                            7.500918   7.002186   5.970851
# Bahamas                               2.451848   2.326735   2.293188
# Bahrain                                    NaN        NaN        NaN
# Bangladesh                           19.612814  19.243465  19.010699
# Barbados                              3.106969   2.804443   3.157018
# Belarus                               9.752112   9.343416   9.775958
# Belgium                               0.901323   0.881363   0.669808
# Belize                               14.608991  12.271381  12.130277
# Benin                                      NaN        NaN        NaN
# Bermuda                               0.895578   0.799296   0.821072
# Bhutan                               22.135448  19.232099  18.979921
# Bolivia                              13.876111  12.877394  13.469405
# Bosnia and Herzegovina               10.416051   8.801428   7.919462
# Botswana                              1.829592   2.033574   1.984370
# Brazil                                5.467357   5.562714   5.914162
# ...                                        ...        ...        ...
# United States                         1.042895   1.130170   1.220378
# Uruguay                              10.731206  10.188828  10.877703
# USSR                                       NaN        NaN        NaN
# Uzbekistan                           26.138893  23.951213  21.363444
# Wallis et Futuna                           NaN        NaN        NaN
# Vanuatu                              20.558779  20.486118  20.115411
# Venezuela                             3.977650   4.194158        NaN
# West Bank and Gaza                         NaN        NaN        NaN
# West Germany                               NaN        NaN        NaN
# Western Sahara                             NaN        NaN        NaN
# Vietnam                              20.404900  20.359618  22.213977
# Virgin Islands (U.S.)                      NaN        NaN        NaN
# North Yemen (former)                       NaN        NaN        NaN
# South Yemen (former)                       NaN        NaN        NaN
# Yemen                                10.146918  10.383171   8.987511
# Yugoslavia                                 NaN        NaN        NaN
# Zambia                               22.439832  21.764341  18.947539
# Zimbabwe                             20.281820  21.597907  19.398885
# Åland                                      NaN        NaN        NaN
# South Sudan                                NaN        NaN        NaN
# Christian                                  NaN        NaN        NaN
# Coastline                                  NaN        NaN        NaN
# Curaçao                                    NaN        NaN        NaN
# Sint Maarten (Dutch part)                  NaN        NaN        NaN
# St. Martin (French part)                   NaN        NaN        NaN
# Antarctica                                 NaN        NaN        NaN
# Virgin Islands, British                    NaN        NaN        NaN
# Hawaiian Trade Zone                        NaN        NaN        NaN
# U.S. Pacific Islands                       NaN        NaN        NaN
# Wake Island                                NaN        NaN        NaN
#
#                                           2009       2010       2011
# Agriculture, value added (% of GDP)
# Abkhazia                                   NaN        NaN        NaN
# Afghanistan                          31.177550  29.915323        NaN
# Akrotiri and Dhekelia                      NaN        NaN        NaN
# Albania                              20.401935  20.160029  20.045320
# Algeria                               6.915571   6.915571        NaN
# American Samoa                             NaN        NaN        NaN
# Andorra                                    NaN        NaN        NaN
# Angola                               10.202085   9.842185  10.058888
# Anguilla                                   NaN        NaN        NaN
# Antigua and Barbuda                   1.771181   2.000781        NaN
# Argentina                             7.503740  10.003471   9.092057
# Armenia                              18.913892  19.577842  20.659376
# Aruba                                      NaN        NaN        NaN
# Australia                             2.365473   2.284059        NaN
# Austria                               1.528136   1.531411        NaN
# Azerbaijan                            6.648044   5.753012   5.758272
# Bahamas                               2.077301   2.212097   2.179119
# Bahrain                                    NaN        NaN        NaN
# Bangladesh                           18.728447  18.587816  18.430956
# Barbados                              3.027063        NaN        NaN
# Belarus                               9.434592   9.224604   8.132726
# Belgium                               0.671758   0.697392        NaN
# Belize                                     NaN        NaN        NaN
# Benin                                      NaN        NaN        NaN
# Bermuda                               0.769960   0.772928        NaN
# Bhutan                               18.748089        NaN        NaN
# Bolivia                              13.829343  12.853137  11.747903
# Bosnia and Herzegovina                7.838391   7.599480   8.699479
# Botswana                              2.952275   2.470568   2.464853
# Brazil                                5.626726   5.304227   5.456271
# ...                                        ...        ...        ...
# United States                         1.103414   1.180634        NaN
# Uruguay                               9.784916   9.470537  10.075090
# USSR                                       NaN        NaN        NaN
# Uzbekistan                           19.504980  19.529403  18.899358
# Wallis et Futuna                           NaN        NaN        NaN
# Vanuatu                              19.714399        NaN        NaN
# Venezuela                                  NaN        NaN        NaN
# West Bank and Gaza                         NaN        NaN        NaN
# West Germany                               NaN        NaN        NaN
# Western Sahara                             NaN        NaN        NaN
# Vietnam                              20.911004  20.578733  19.662869
# Virgin Islands (U.S.)                      NaN        NaN        NaN
# North Yemen (former)                       NaN        NaN        NaN
# South Yemen (former)                       NaN        NaN        NaN
# Yemen                                 9.863141   7.700269        NaN
# Yugoslavia                                 NaN        NaN        NaN
# Zambia                               21.553184   9.158563  20.721860
# Zimbabwe                             17.209262  16.002422  12.760264
# Åland                                      NaN        NaN        NaN
# South Sudan                                NaN        NaN        NaN
# Christian                                  NaN        NaN        NaN
# Coastline                                  NaN        NaN        NaN
# Curaçao                                    NaN        NaN        NaN
# Sint Maarten (Dutch part)                  NaN        NaN        NaN
# St. Martin (French part)                   NaN        NaN        NaN
# Antarctica                                 NaN        NaN        NaN
# Virgin Islands, British                    NaN        NaN        NaN
# Hawaiian Trade Zone                        NaN        NaN        NaN
# U.S. Pacific Islands                       NaN        NaN        NaN
# Wake Island                                NaN        NaN        NaN
#
# [270 rows x 51 columns]

# %%
# Now do the same for the percent of workforce data (note: do not re-import libraries)

# Set variables for file and index column
file = 'prac1-data2.csv' #see above
colname = 'Total agriculture workers (%)' #open the csv and have a look

# Read in the percent of gdp data
ag_wkf = pandas.read_csv(file, index_col= colname)
print(ag_wkf.shape)
# Out:
# (176, 29)

# %%
# Take a look at the data
ag_wkf
# Out:
#                                     1980       1981       1982       1983  \
# Total agriculture workers (%)
# Algeria                              NaN        NaN        NaN        NaN
# American Samoa                       NaN        NaN        NaN        NaN
# Angola                               NaN        NaN        NaN        NaN
# Anguilla                             NaN        NaN        NaN        NaN
# Antigua and Barbuda                  NaN        NaN        NaN        NaN
# Argentina                            NaN        NaN   0.100000   0.300000
# Armenia                              NaN        NaN        NaN        NaN
# Aruba                                NaN        NaN        NaN        NaN
# Australia                       6.500000   6.500000   6.400000   6.600000
# Austria                              NaN        NaN        NaN   9.900000
# Azerbaijan                           NaN        NaN        NaN  33.400002
# Bahamas                              NaN        NaN        NaN        NaN
# Bahrain                              NaN   2.700000   2.600000        NaN
# Bangladesh                           NaN        NaN        NaN        NaN
# Barbados                             NaN   9.400000   8.600000   8.000000
# Belgium                         3.100000   3.100000   3.100000   3.100000
# Belize                               NaN        NaN        NaN        NaN
# Bermuda                              NaN        NaN        NaN        NaN
# Bhutan                               NaN        NaN        NaN        NaN
# Bolivia                        46.500000  46.299999  46.400002  47.400002
# Botswana                             NaN        NaN        NaN        NaN
# Brazil                               NaN  29.299999  29.500000  27.100000
# British Virgin Islands               NaN        NaN        NaN        NaN
# Brunei                               NaN        NaN        NaN        NaN
# Bulgaria                       24.400000  23.700001  22.900000  22.100000
# Burkina Faso                         NaN        NaN        NaN        NaN
# Cambodia                             NaN        NaN        NaN        NaN
# Cameroon                             NaN        NaN        NaN        NaN
# Canada                          5.400000   5.500000   5.300000   5.500000
# Cayman Islands                       NaN        NaN        NaN        NaN
# ...                                  ...        ...        ...        ...
# Saint Helena                         NaN        NaN        NaN        NaN
# Saint-Pierre-et-Miquelon             NaN        NaN        NaN        NaN
# Suriname                             NaN        NaN  16.500000        NaN
# Sweden                          5.600000   5.600000   5.600000   5.400000
# Switzerland                     6.900000   6.600000   6.400000   6.400000
# Syria                                NaN        NaN        NaN  30.600000
# Taiwan                               NaN        NaN        NaN        NaN
# Tajikistan                           NaN        NaN        NaN        NaN
# Tanzania                             NaN        NaN        NaN        NaN
# Thailand                       70.800003  64.199997  61.500000  63.099998
# Macedonia, FYR                       NaN        NaN        NaN        NaN
# Tonga                                NaN        NaN        NaN        NaN
# Trinidad and Tobago            10.200000   9.800000   8.700000   8.600000
# Tunisia                        33.400002  32.500000  31.600000        NaN
# Turkey                               NaN        NaN   4.300000   4.800000
# Turks and Caicos Islands             NaN        NaN        NaN        NaN
# Uganda                               NaN        NaN        NaN        NaN
# Ukraine                              NaN        NaN        NaN        NaN
# United Arab Emirates                 NaN        NaN        NaN        NaN
# United Kingdom                  2.600000   2.600000   2.600000   2.600000
# United States                   3.600000   3.500000   3.600000   3.500000
# Uruguay                              NaN        NaN        NaN        NaN
# Uzbekistan                           NaN        NaN        NaN        NaN
# Venezuela                      15.000000  14.600000  14.500000  14.800000
# Vietnam                              NaN        NaN        NaN        NaN
# West Bank and Gaza                   NaN        NaN        NaN        NaN
# Yemen, Rep.                          NaN        NaN        NaN        NaN
# Zambia                               NaN        NaN        NaN        NaN
# Zimbabwe                             NaN        NaN        NaN        NaN
# NaN                                  NaN        NaN        NaN        NaN
#
#                                     1984       1985       1986       1987  \
# Total agriculture workers (%)
# Algeria                              NaN        NaN        NaN        NaN
# American Samoa                       NaN        NaN        NaN        NaN
# Angola                               NaN        NaN        NaN        NaN
# Anguilla                             NaN        NaN        NaN        NaN
# Antigua and Barbuda                  NaN        NaN        NaN        NaN
# Argentina                       0.300000        NaN        NaN        NaN
# Armenia                              NaN        NaN        NaN        NaN
# Aruba                                NaN        NaN        NaN        NaN
# Australia                       6.200000   6.200000   6.000000   5.700000
# Austria                         9.400000   9.000000   8.600000   8.600000
# Azerbaijan                     33.400002  33.200001  33.099998  33.700001
# Bahamas                              NaN        NaN   5.000000        NaN
# Bahrain                              NaN        NaN        NaN        NaN
# Bangladesh                     58.799999  57.700001  57.099998        NaN
# Barbados                        9.100000   8.500000   8.200000   8.000000
# Belgium                         3.100000   3.100000   3.000000   2.900000
# Belize                               NaN        NaN        NaN        NaN
# Bermuda                              NaN        NaN        NaN        NaN
# Bhutan                               NaN        NaN        NaN        NaN
# Bolivia                        47.299999  47.400002  47.400002  47.400002
# Botswana                             NaN  57.900002        NaN        NaN
# Brazil                         29.799999  28.600000  25.900000  24.600000
# British Virgin Islands               NaN        NaN        NaN        NaN
# Brunei                               NaN        NaN        NaN        NaN
# Bulgaria                       21.500000  21.000000  20.400000  19.700001
# Burkina Faso                         NaN        NaN        NaN        NaN
# Cambodia                             NaN        NaN        NaN        NaN
# Cameroon                             NaN        NaN  76.900002        NaN
# Canada                          5.400000   5.100000   4.900000   4.600000
# Cayman Islands                       NaN        NaN        NaN        NaN
# ...                                  ...        ...        ...        ...
# Saint Helena                         NaN        NaN        NaN        NaN
# Saint-Pierre-et-Miquelon             NaN        NaN   5.000000        NaN
# Suriname                             NaN        NaN   9.200000        NaN
# Sweden                          5.100000   4.800000   4.000000   4.000000
# Switzerland                     6.200000   6.100000   5.700000   5.300000
# Syria                          25.500000        NaN        NaN        NaN
# Taiwan                               NaN        NaN        NaN        NaN
# Tajikistan                           NaN        NaN        NaN        NaN
# Tanzania                             NaN        NaN        NaN        NaN
# Thailand                       64.400002  68.400002  66.699997  64.400002
# Macedonia, FYR                       NaN        NaN        NaN        NaN
# Tonga                          43.200001        NaN        NaN        NaN
# Trinidad and Tobago             9.300000  10.800000  11.100000  11.700000
# Tunisia                              NaN        NaN        NaN        NaN
# Turkey                          4.400000  45.000000        NaN        NaN
# Turks and Caicos Islands             NaN        NaN        NaN        NaN
# Uganda                               NaN        NaN        NaN        NaN
# Ukraine                              NaN        NaN        NaN  20.400000
# United Arab Emirates                 NaN        NaN        NaN        NaN
# United Kingdom                  2.500000   2.500000   2.500000   2.400000
# United States                   3.300000   3.100000   3.100000   3.000000
# Uruguay                              NaN        NaN        NaN        NaN
# Uzbekistan                           NaN        NaN        NaN        NaN
# Venezuela                      16.100000  16.200001  15.500000  14.300000
# Vietnam                              NaN        NaN        NaN        NaN
# West Bank and Gaza                   NaN        NaN        NaN        NaN
# Yemen, Rep.                          NaN        NaN        NaN        NaN
# Zambia                               NaN        NaN        NaN        NaN
# Zimbabwe                             NaN        NaN        NaN        NaN
# NaN                                  NaN        NaN        NaN        NaN
#
#                                     1988       1989     ...            1999  \
# Total agriculture workers (%)                           ...
# Algeria                              NaN        NaN     ...             NaN
# American Samoa                       NaN        NaN     ...             NaN
# Angola                               NaN        NaN     ...             NaN
# Anguilla                             NaN        NaN     ...        2.300000
# Antigua and Barbuda                  NaN        NaN     ...             NaN
# Argentina                            NaN        NaN     ...        0.700000
# Armenia                              NaN        NaN     ...             NaN
# Aruba                                NaN        NaN     ...             NaN
# Australia                       5.800000   5.300000     ...        5.000000
# Austria                         8.100000   7.900000     ...        6.200000
# Azerbaijan                     32.700001  31.600000     ...       42.299999
# Bahamas                              NaN   4.400000     ...        4.000000
# Bahrain                              NaN        NaN     ...             NaN
# Bangladesh                           NaN  64.900002     ...             NaN
# Barbados                        7.800000   6.600000     ...        4.300000
# Belgium                              NaN        NaN     ...        2.000000
# Belize                               NaN        NaN     ...       27.500000
# Bermuda                              NaN        NaN     ...             NaN
# Bhutan                               NaN        NaN     ...             NaN
# Bolivia                        47.400002   2.200000     ...        3.800000
# Botswana                             NaN        NaN     ...             NaN
# Brazil                         24.200001  23.200001     ...             NaN
# British Virgin Islands               NaN        NaN     ...             NaN
# Brunei                               NaN        NaN     ...             NaN
# Bulgaria                       19.299999  18.700001     ...       25.799999
# Burkina Faso                         NaN        NaN     ...             NaN
# Cambodia                             NaN        NaN     ...             NaN
# Cameroon                             NaN        NaN     ...             NaN
# Canada                          4.400000   4.300000     ...        3.600000
# Cayman Islands                       NaN        NaN     ...             NaN
# ...                                  ...        ...     ...             ...
# Saint Helena                         NaN        NaN     ...             NaN
# Saint-Pierre-et-Miquelon             NaN   2.100000     ...             NaN
# Suriname                             NaN        NaN     ...        6.100000
# Sweden                          3.900000   3.600000     ...        2.500000
# Switzerland                     4.900000   4.500000     ...        4.800000
# Syria                                NaN  26.500000     ...       27.799999
# Taiwan                               NaN        NaN     ...        8.200000
# Tajikistan                           NaN        NaN     ...             NaN
# Tanzania                             NaN        NaN     ...             NaN
# Thailand                       66.400002  66.599998     ...       48.200001
# Macedonia, FYR                       NaN        NaN     ...             NaN
# Tonga                                NaN        NaN     ...             NaN
# Trinidad and Tobago            13.000000  13.800000     ...        8.100000
# Tunisia                              NaN  25.799999     ...             NaN
# Turkey                         47.400002  48.200001     ...       41.400002
# Turks and Caicos Islands             NaN        NaN     ...             NaN
# Uganda                               NaN        NaN     ...             NaN
# Ukraine                        19.700001  19.100000     ...       22.700001
# United Arab Emirates                 NaN        NaN     ...             NaN
# United Kingdom                  2.300000   2.200000     ...        1.600000
# United States                   2.900000   2.900000     ...        2.600000
# Uruguay                              NaN        NaN     ...        3.900000
# Uzbekistan                           NaN        NaN     ...       38.500000
# Venezuela                      13.500000  13.400000     ...             NaN
# Vietnam                              NaN        NaN     ...       65.000000
# West Bank and Gaza                   NaN        NaN     ...       12.600000
# Yemen, Rep.                          NaN        NaN     ...       54.099998
# Zambia                               NaN        NaN     ...             NaN
# Zimbabwe                             NaN        NaN     ...       60.000000
# NaN                                  NaN        NaN     ...             NaN
#
#                                     2000       2001       2002       2003  \
# Total agriculture workers (%)
# Algeria                              NaN  21.100000        NaN  21.100000
# American Samoa                       NaN        NaN        NaN        NaN
# Angola                               NaN        NaN        NaN        NaN
# Anguilla                             NaN   2.900000        NaN        NaN
# Antigua and Barbuda                  NaN   2.600000        NaN        NaN
# Argentina                       0.700000   0.800000   1.000000   1.400000
# Armenia                              NaN   5.400000  45.299999  46.000000
# Aruba                                NaN        NaN        NaN        NaN
# Australia                       5.000000   4.800000   4.500000   3.900000
# Austria                         5.900000   5.700000   5.700000   5.600000
# Azerbaijan                     41.000000  40.000000  40.200001  38.200001
# Bahamas                              NaN   4.200000   3.700000   3.000000
# Bahrain                              NaN   1.500000        NaN        NaN
# Bangladesh                     62.099998        NaN        NaN  51.700001
# Barbados                        3.700000   4.200000   4.000000   4.600000
# Belgium                         1.800000   1.600000   1.700000   1.700000
# Belize                               NaN        NaN        NaN        NaN
# Bermuda                         1.400000        NaN        NaN        NaN
# Bhutan                               NaN        NaN        NaN        NaN
# Bolivia                         4.900000  41.500000  39.599998        NaN
# Botswana                       19.700001  12.400000        NaN  21.200001
# Brazil                         18.500000        NaN  20.600000  20.700001
# British Virgin Islands               NaN        NaN        NaN        NaN
# Brunei                               NaN   1.400000        NaN        NaN
# Bulgaria                       26.200001        NaN  25.799999  10.100000
# Burkina Faso                         NaN        NaN        NaN        NaN
# Cambodia                       73.699997  70.199997        NaN        NaN
# Cameroon                             NaN  60.599998        NaN        NaN
# Canada                          3.300000   2.800000   2.800000   2.800000
# Cayman Islands                       NaN        NaN        NaN        NaN
# ...                                  ...        ...        ...        ...
# Saint Helena                         NaN        NaN        NaN        NaN
# Saint-Pierre-et-Miquelon             NaN        NaN        NaN        NaN
# Suriname                             NaN        NaN        NaN        NaN
# Sweden                          2.400000   2.300000   2.100000   2.100000
# Switzerland                     4.500000   4.200000   4.100000   4.100000
# Syria                          32.900002  30.600000  31.200001  27.000000
# Taiwan                          7.800000   7.500000   7.500000   7.300000
# Tajikistan                           NaN        NaN        NaN        NaN
# Tanzania                             NaN  82.099998        NaN        NaN
# Thailand                       48.500000  46.000000  46.099998  44.900002
# Macedonia, FYR                       NaN        NaN  23.900000  22.000000
# Tonga                                NaN        NaN        NaN  31.799999
# Trinidad and Tobago             7.200000   7.800000   6.900000   5.900000
# Tunisia                              NaN        NaN        NaN        NaN
# Turkey                         36.000000  37.599998  34.900002  33.900002
# Turks and Caicos Islands             NaN   2.900000   1.700000   1.400000
# Uganda                               NaN        NaN        NaN  68.699997
# Ukraine                        23.400000  20.900000  20.600000  20.400000
# United Arab Emirates            7.900000        NaN        NaN        NaN
# United Kingdom                  1.500000   1.400000   1.400000   1.300000
# United States                   2.600000   2.400000   2.500000   1.700000
# Uruguay                         4.100000   4.200000   4.200000   4.500000
# Uzbekistan                           NaN        NaN        NaN        NaN
# Venezuela                            NaN        NaN        NaN  10.700000
# Vietnam                        65.300003  64.000000  62.000000  59.700001
# West Bank and Gaza             13.700000  11.700000  14.800000  15.700000
# Yemen, Rep.                          NaN        NaN        NaN        NaN
# Zambia                         71.599998        NaN        NaN        NaN
# Zimbabwe                             NaN        NaN        NaN        NaN
# NaN                                  NaN        NaN        NaN        NaN
#
#                                     2004       2005       2006       2007  \
# Total agriculture workers (%)
# Algeria                        20.700001        NaN        NaN        NaN
# American Samoa                       NaN        NaN        NaN        NaN
# Angola                               NaN        NaN        NaN        NaN
# Anguilla                             NaN        NaN        NaN        NaN
# Antigua and Barbuda                  NaN        NaN        NaN        NaN
# Argentina                       1.200000   1.100000   0.800000        NaN
# Armenia                        46.900002  46.200001  46.200001        NaN
# Aruba                                NaN        NaN        NaN        NaN
# Australia                       3.800000   3.600000   3.500000   3.400000
# Austria                         5.000000   5.500000   5.500000   5.700000
# Azerbaijan                     39.500000  39.299999  39.500000  38.599998
# Bahamas                         4.400000   3.500000   2.500000   2.300000
# Bahrain                              NaN        NaN        NaN        NaN
# Bangladesh                           NaN  48.099998        NaN        NaN
# Barbados                        3.300000        NaN        NaN        NaN
# Belgium                         2.000000   2.000000   2.000000        NaN
# Belize                               NaN  19.500000        NaN        NaN
# Bermuda                              NaN        NaN        NaN        NaN
# Bhutan                               NaN  43.599998        NaN        NaN
# Bolivia                              NaN        NaN        NaN        NaN
# Botswana                             NaN  29.900000        NaN        NaN
# Brazil                         21.000000  20.500000  19.299999        NaN
# British Virgin Islands               NaN        NaN        NaN        NaN
# Brunei                               NaN        NaN        NaN        NaN
# Bulgaria                        9.700000   8.900000   8.100000   7.500000
# Burkina Faso                         NaN        NaN        NaN        NaN
# Cambodia                       39.799999        NaN        NaN        NaN
# Cameroon                             NaN        NaN        NaN        NaN
# Canada                          2.700000   2.700000   2.600000   2.500000
# Cayman Islands                       NaN   1.700000   2.300000   1.800000
# ...                                  ...        ...        ...        ...
# Saint Helena                         NaN        NaN        NaN        NaN
# Saint-Pierre-et-Miquelon             NaN        NaN        NaN        NaN
# Suriname                        8.000000        NaN        NaN        NaN
# Sweden                          2.100000   2.000000   2.000000   2.200000
# Switzerland                     3.800000   3.800000   3.700000   4.000000
# Syria                                NaN        NaN        NaN        NaN
# Taiwan                          6.600000   5.900000        NaN        NaN
# Tajikistan                     55.500000        NaN        NaN        NaN
# Tanzania                             NaN        NaN  76.500000        NaN
# Thailand                       42.299999  42.599998  42.099998  41.700001
# Macedonia, FYR                 16.799999  19.500000  20.100000  18.200001
# Tonga                                NaN        NaN        NaN        NaN
# Trinidad and Tobago             4.600000   4.300000        NaN        NaN
# Tunisia                              NaN        NaN        NaN        NaN
# Turkey                         34.000000  29.500000  27.299999  26.400000
# Turks and Caicos Islands        2.000000   1.700000        NaN        NaN
# Uganda                               NaN        NaN        NaN        NaN
# Ukraine                        19.700001  19.400000  17.600000  16.700001
# United Arab Emirates                 NaN   4.900000        NaN        NaN
# United Kingdom                  1.300000   1.400000   1.300000   1.400000
# United States                   1.600000   1.600000   1.500000   1.400000
# Uruguay                         5.000000   4.600000  11.100000  11.000000
# Uzbekistan                           NaN        NaN        NaN        NaN
# Venezuela                            NaN        NaN   9.100000   8.700000
# Vietnam                        57.900002        NaN        NaN        NaN
# West Bank and Gaza             15.900000  14.600000  16.100000  15.600000
# Yemen, Rep.                          NaN        NaN        NaN        NaN
# Zambia                               NaN        NaN        NaN        NaN
# Zimbabwe                             NaN        NaN        NaN        NaN
# NaN                                  NaN        NaN        NaN        NaN
#
#                                Unnamed: 29
# Total agriculture workers (%)
# Algeria                                NaN
# American Samoa                         NaN
# Angola                                 NaN
# Anguilla                               NaN
# Antigua and Barbuda                    NaN
# Argentina                              NaN
# Armenia                                NaN
# Aruba                                  NaN
# Australia                              NaN
# Austria                                NaN
# Azerbaijan                             NaN
# Bahamas                                NaN
# Bahrain                                NaN
# Bangladesh                             NaN
# Barbados                               NaN
# Belgium                                NaN
# Belize                                 NaN
# Bermuda                                NaN
# Bhutan                                 NaN
# Bolivia                                NaN
# Botswana                               NaN
# Brazil                                 NaN
# British Virgin Islands                 NaN
# Brunei                                 NaN
# Bulgaria                               NaN
# Burkina Faso                           NaN
# Cambodia                               NaN
# Cameroon                               NaN
# Canada                                 NaN
# Cayman Islands                         NaN
# ...                                    ...
# Saint Helena                           NaN
# Saint-Pierre-et-Miquelon               NaN
# Suriname                               NaN
# Sweden                                 NaN
# Switzerland                            NaN
# Syria                                  NaN
# Taiwan                                 NaN
# Tajikistan                             NaN
# Tanzania                               NaN
# Thailand                               NaN
# Macedonia, FYR                         NaN
# Tonga                                  NaN
# Trinidad and Tobago                    NaN
# Tunisia                                NaN
# Turkey                                 NaN
# Turks and Caicos Islands               NaN
# Uganda                                 NaN
# Ukraine                                NaN
# United Arab Emirates                   NaN
# United Kingdom                         NaN
# United States                          NaN
# Uruguay                                NaN
# Uzbekistan                             NaN
# Venezuela                              NaN
# Vietnam                                NaN
# West Bank and Gaza                     NaN
# Yemen, Rep.                            NaN
# Zambia                                 NaN
# Zimbabwe                               NaN
# NaN                                    NaN
#
# [176 rows x 29 columns]

# %% [markdown]
# ### Clean/pre-process data

# %%
# Take the last 5 years of the GDP data
ag_gdp_cln = ag_gdp.filter(['2002','2003','2004','2005','2006'], axis=1)
print(ag_gdp_cln.shape)

# Just select the countries we are interested in by referencing the index
ag_gdp_au = ag_gdp_cln.ix['Australia']
ag_gdp_nz = ag_gdp_cln.ix['New Zealand']
# Out:
# (270, 5)

# %%
# Take a look at the data for AU
ag_gdp_au
# Out:
# 2002    4.438795
# 2003    3.270656
# 2004    3.480123
# 2005    3.265037
# 2006    3.092147
# Name: Australia, dtype: float64

# %%
# Take a look at the data for NZ
ag_gdp_nz
# Out:
# 2002    6.829683
# 2003    6.700610
# 2004    6.331668
# 2005    5.402917
# 2006    5.635167
# Name: New Zealand, dtype: float64

# %% [markdown]
# ### Perform analysis

# %%
# What is the problem with the NZ data?
# What do we need to do?
# For now, we don't do any more analysis - we are more interested in the process.

# %% [markdown]
# ### Visualise analytics

# %%
# Plot the 2 countries
plt.plot(ag_gdp_au)
plt.plot(ag_gdp_nz)

# %%
# Add labels and set colours
plt.plot(ag_gdp_au,'g-',label='Australia')
plt.plot(ag_gdp_nz,'m-',label='New Zealand')

# Create legend.
plt.legend(loc='upper right')
plt.xlabel('Year')
plt.ylabel('Agriculture to GDP (%)')
# Out:
# Text(0,0.5,'Agriculture to GDP (%)')

# %% [markdown]
# ### Document analytics
#
# 1. What is the concern?
# 2. What data did we use?
# 3. How did we analyse it, what decisions and why?
# 4. What do the visualisations tell us?
# 5. What is the recommendation for the concern? What other information would be helpful? What *doesn't* the data tell us? Can we make inferences?
