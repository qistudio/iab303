# %% [markdown]
# <div class="alert alert-block alert-info"><b>IAB303</b> - Data Analytics for Business Insight</div>

# %% [markdown]
# # Module 7 -  Stregths and Weaknesses
#
# In this module we focus on analysis of data that is **internal** to the business, and look at why it is important for identifying structural problems or advantages in the organisation

# %% [markdown]
# ## Learning about Organisations - Why are people leaving my company?

# %% [markdown]
# In this tutorial, you will continue the analysis that we started in the studio session.
# If you did not attend it, we strongly advise you to review the recording.
#
# ### Business Concern: Why are the best and most experienced employees leaving the company?

# %%
import pandas as pd
import numpy as np
from matplotlib.pyplot import figure

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# %%html
# <style>
# table {float:left}
# </style>
# Out:
# <style>
# table {float:left}
# </style>

# %% [markdown]
# ### DATASET INFORMATION
#
# The Human Resources department of the company has collected the follwoing information about the staff members
#
# | Variable              | Descriptions                                |
# |-----------------------|---------------------------------------------|
# | satisfaction_level    | Satisfaction Level                          |
# | last_evaluation       | Last evaluation                             |
# | number_project        | Number of projects                          |
# | average_montly_hours  | Average monthly hours                       |
# | time_spend_company    | Time spent at the company                   |
# | Work_accident         | Whether they have had a work accident       |
# | left                  | Whether the employee has left               |
# | promotion_last_5years | Whether had a promotion in the last 5 years |
# | department                 | Departments                   |
# | salary                | Salary                                      |

# %% [markdown]
# ### Taking a look at the dataset

# %%
# dataset filepath
dataset_path = "data/dataset_7.csv"

# load dataset into a dataframe
data =   # YOUR ANSWER HERE
data

# %% [markdown]
# Let's first encode the "salary" to integers. Note that the variable "Salary" is called a categorical variable. It expresses the categories low, medium and high.

# %%
# how many categories of salary do we have?
# YOUR ANSWER HERE
# Out:
# array(['high', 'low', 'medium'], dtype=object)

# %%
# encode the categorical variable salary as
# low -> 0
# medium -> 1
# high -> 2
data['salary'] = #YOUR ANSWER HERE

# %% [markdown]
# ### What are the General Descriptive Statistics of this Dataset?

# %%
# descriptive statistics
descr = # YOUR ANSWER HERE
descr

# %% [markdown]
# #### Graphical Representation of Descriptive Statistics: Box Plots
#
# Boxplot is a good statistical graphic to analyze the dataset and indentify outliers values. An outlier is as observation that lies an abnormal distance from other values, in this case the analyst have to decide what is considered abnormal.

# %%
f, axes = plt.subplots(3,2, figsize=(10,10), sharex=True)

plt.subplots_adjust(wspace=1)# adjust the space between the plots

#
# plot a boxplot of satisfaction_level to see if there are outliers
sns.boxplot( x= ???,  data=data, orient='v', ax=axes[0,0])

# plot a boxplot of last_evaluation to see if there are outliers
sns.boxplot( x= ???,  data=data, orient='v',ax=axes[0,1])

# plot a boxplot of number_project to see if there are outliers
sns.boxplot( x= ???,  data=data, orient='v',ax=axes[1,0])

# plot a boxplot of average_montly_hours to see are there is outliers
sns.boxplot( x= ???,  data=data, orient='v',ax=axes[1,1])

# plot a boxplot of salary to see are there is outliers
sns.boxplot( x= ???,  data=data, orient='v',ax=axes[2,0])

# plot a boxplot of average_montly_hours to see are there is outliers
sns.boxplot( x= ???,  data=data, orient='v',ax=axes[2,1])

# %% [markdown]
# What is the average of
# - satisfaction_level
# - last_evaluation
# - number_project
# - average_montly_hours
# - salary
# - time_spend_company
#
# Can you comment of the skewness of the distributions?

# %% [markdown]
# ### Correlation Analysis
#
# Apply a correlation matrix to the dataset

# %%
correlation_matrix = # your answer here
correlation_matrix

# %% [markdown]
# What are the most impactful correlations that you see in this table? Can you understand why? How to they relate to our business concern?
#
# **YOUR ANSWER**
# -
# -
# -

# %%
sns.set(style='white')

mask = np.zeros_like(correlation_matrix, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(13,8))

cmap = sns.diverging_palette(10,220, as_cmap=True)

ax = sns.heatmap(correlation_matrix, mask=mask, 
                 cmap=cmap, vmax= .5, annot=True, annot_kws= {'size':11}, 
                 square=True, xticklabels=True, yticklabels=True, linewidths=.5, 
                 cbar_kws={'shrink': .5}, ax=ax)

ax.set_title('Correlation between variables', fontsize=20);

# %% [markdown]
# In the studio session, we started to draw some hypothesis of **why employees where leaving the company**. You will now continue the analysis, but for different variables and hypothesis.

# %% [markdown]
# #### From the Studio Session:

# %% [markdown]
# In terms of Salary:
# - the majority of the employees who had a low salary left
# - the sales department had the highest number of emplyees leaving. However, this is still not enough to draw a conclusion. Many employees with low salary also stayed in the company
# - the technical and support departments also pay a low salary range to its employees, which might be another reason why they are leaving
#
# In terms of Satisfaction Levels:
# It is possible to see 3 interesting peaks in the satisfaction levels of the employees that left the company.
#
# - We have a peak of employees who are totally disappointed.
# - Another peak at 0.4, representing another group with the satisfaction level below the average.
# - And another amount in the range 0.7 and 0.9, with employees that left, although the high satisfaction (probably because they wanted to progree in the career in another job)
# - Clear drop in satisfaction when employees are working on 6 or more projects (overworking...)

# %% [markdown]
# ### Answer the Following Questions:

# %% [markdown]
# #### Hypothesis 3: Do Employees Leave the Company Because of Safety Problems?

# %%
# YOUR ANSWER HERE

# %% [markdown]
# #### Hypothesis 4: Do Employees Leave the Company Because they cannot progress in their career (get promoted)?

# %%
# YOUR ANSWER HERE

# %% [markdown]
# #### Hypothesis 5: Employees who are leaving have a good or bad performance? Are they working too much?

# %%
# YOUR ANSWER HERE

# %% [markdown]
# ### Answering the Business Concern

# %%
filtered_data = data[(data.last_evaluation >= 0.70) | (data.time_spend_company >=4) | (data.number_project >= 5)]

correlation_matrix = filtered_data.corr()

sns.set(style='white')

mask = np.zeros_like(correlation_matrix, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Insert the graphic
f, ax = plt.subplots(figsize=(13,8))

cmap = sns.diverging_palette(10,220, as_cmap=True)

#Draw heat map mask
ax = sns.heatmap(corr2, mask=mask, cmap=cmap, vmax= .5, annot=True, annot_kws= {'size':11}, square=True, xticklabels=True, yticklabels=True, linewidths=.5, 
           cbar_kws={'shrink': .5}, ax=ax)
ax.set_title('Correlation: Why Valuable Employees Tend to Leave', fontsize=20);

# %% [markdown]
# What do you read from this graph?
#
# **YOUR ANSWER HERE**

# %% [markdown]
# ### TOWS Analysis
#
# Go to www.wooclap.com/IAB303. Complete the information about Strengths and Weaknesses according to your analysis. Make a TOWS analysis by connecting the weaknesses that you identified with Opportunities and Threats. As well as Strengths with Opportinities and Threats.
#
# <img src="graphics/7_1.png" width="700" ></img>
