# %% [markdown]
# ## PRACTICAL :: Social Media Analysis
#
# 1. Connect to Twitter API and extract tweets
# 2. Basic sentiment analysis
# 3. Basic visualisation

# %% [markdown]
# ## Connect to Twitter API and extract tweets

# %%
# General
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-5af4c938d4c4> in <module>()
#       1 # General
# ----> 2 import tweepy           # To consume Twitter's API
#       3 import pandas as pd     # To handle data
#       4 import numpy as np      # For number computing
#
# ModuleNotFoundError: No module named 'tweepy'

# %% [markdown]
# Store Twitter application credentials

# %%
# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = 'x8kiAaw5kegIYqNlsKFGFNRia'
CONSUMER_SECRET = 'XVyJTaQMT0uNsMAyyPzZAsgxP2ykEU6czWxRWggwceF2D1cQMZ'

# Access:
ACCESS_TOKEN  = '890735734100905985-PljAE2qePUozbwqkTyNkSRfxIy1MLKk'
ACCESS_SECRET = 'Ji10kzq3AlzCcP8B8Mv0ZUXgGyKwzQnF17S64oHslfnov'

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth)
    return api

# %% [markdown]
# Extract Tweets

# %%
# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name="theblackpanther", count=50)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("5 recent tweets:\n")
for tweet in tweets[:5]:
    print(tweet.text)
    print()
# Out:
# Number of tweets extracted: 50.
#
# 5 recent tweets:
#
# RT @ApolloTheater: WAKANDA takes over #Harlem! Tune in live on Facebook now!! 🙅🏾#BlackPantherApollo #WakandaForever https://t.co/ssEnknx6MS
#
# Tonight we’re at the @ApolloTheater for a special #BlackPanther event with @chadwickboseman, @Lupita_Nyongo + Ta-Ne… https://t.co/GX9GUz2viG
#
# RT @Marvel: Tonight we’re at the @ApolloTheater for a special #BlackPanther event with @chadwickboseman, @Lupita_Nyongo + Ta-Nehisi Coates…
#
# #BlackPanther is the #1 movie in the world. How many times have you seen it? https://t.co/o3TN39p09N
#
# RT @GMA: .@Marvel: The Universe Unites! If we reach 1M likes on #HeroActs posts like this one, Marvel &amp; @Disney together will donate $250,0…

# %% [markdown]
# Sentiment Analysis

# %%
from textblob import TextBlob
import re

def clean_tweet(tweet):
    '''
    Utility function to clean the text in a tweet by removing 
    links and special characters using regex.
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

def analize_sentiment(tweet):
    '''
    Utility function to classify the polarity of a tweet
    using textblob.
    '''
    analysis = TextBlob(clean_tweet(tweet))
    if analysis.sentiment.polarity > 0:
        return 1
    elif analysis.sentiment.polarity == 0:
        return 0
    else:
        return -1

# %% [markdown]
# Display Data

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We add relevant data:
data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID']   = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

# We create a column with the result of the analysis:
data['SA'] = np.array([ analize_sentiment(tweet) for tweet in data['Tweets'] ])

# We display the first 10 elements of the dataframe:
display(data.head(30))
# Out:
#                                                Tweets  len  \
# 0   RT @ApolloTheater: WAKANDA takes over #Harlem!...  139
# 1   Tonight we’re at the @ApolloTheater for a spec...  140
# 2   RT @Marvel: Tonight we’re at the @ApolloTheate...  139
# 3   #BlackPanther is the #1 movie in the world. Ho...  100
# 4   RT @GMA: .@Marvel: The Universe Unites! If we ...  144
# 5   Experience the phenomenon for yourself. #Black...  117
# 6   All hail the king. Have you seen #BlackPanther...  108
# 7   Wakanda Forever. See #BlackPanther in theaters...   99
# 8   RT @peteredmiston: Finally got to see #BlackPa...  140
# 9   RT @dev_nicolee: As of yesterday, I've officia...  140
# 10  RT @Selumgirl: I finally saw #BlackPanther, an...  143
# 11  RT @jcharanis: Finally saw #BlackPanther - abs...  140
# 12  RT @KalUndefined: #BlackPanther not only lived...  140
# 13  The people have spoken. #BlackPanther is the #...  128
# 14  Wakanda Forever. Here's a look at some #BlackP...  139
# 15  Wakanda Forever. Here's a look at some #BlackP...  139
# 16  #BlackPanther is the #1 movie in the world. Se...  105
# 17  Experience the phenomenon. Marvel Studios' #Bl...  120
# 18  RT @tumblr: 🚨 Our first-ever video #AnswerTime...  140
# 19  #BlackPanther is the #1 movie in the world. Se...  135
# 20  The king has arrived. Take a look at these #Bl...  140
# 21  The king has arrived. Take a look at these #Bl...  140
